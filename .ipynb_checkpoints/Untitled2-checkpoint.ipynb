# %%
import numpy as np

# %%
d = [ 
     ...:     [90, 30, 45, 0, 120, 180], 
     ...:     [45, -90, -30, 270, 90, 0], 
     ...:     [60, 45, -45, 90, -45, 180] 
     ...: ]

# %%
d = np.array(d)

# %%
d
# Out:
# array([[ 90,  30,  45,   0, 120, 180],
#        [ 45, -90, -30, 270,  90,   0],
#        [ 60,  45, -45,  90, -45, 180]])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(d)
# Out:
# [<matplotlib.lines.Line2D at 0x11ff9b320>,
#  <matplotlib.lines.Line2D at 0x11ff9b470>,
#  <matplotlib.lines.Line2D at 0x11ff9b5c0>,
#  <matplotlib.lines.Line2D at 0x11ff9b710>,
#  <matplotlib.lines.Line2D at 0x11ff9b860>,
#  <matplotlib.lines.Line2D at 0x11ff9b9b0>]

# %%
def capitalize_names(listo):
    capital_list = []
    return [capital_list.append({'first_name':i['first_name'].capitalize(), 'last_name':i['last_name'].capitalize()}) 
 for i in listo]
#     capital_list = []                                                                                          
#     for i in listo:  
#         capital_list.append({'first_name':i['first_name'].capitalize(), 'last_name':i['last_name'].capitalize()}) 
#     return capital_list
    
    
names = []
names.append({'first_name': 'ada', 'last_name': 'lovelace'})
names.append({'first_name': 'marie', 'last_name': 'curie'})

# %%
names
