# %%
import matplotlib.pyplot as plt
import math, random
# %matplotlib inline

x = list(range(150))
plt.plot(x, c="red")
plt.xlim(-20, 200)
plt.ylim(-5, 160)
#plt.show()
# Out:
# (-5, 160)

# %%
x1 = [random.randint(-7, 52) + i for i in range(200)]
x2 = [random.randint(2, 4) - i for i in range(200)]

# %%
plt.plot(x1)
plt.plot(x2)

# %%
fig = plt.figure()  # an empty figure with no axes
fig.suptitle('No axes on this figure')
# Out:
# Text(0.5, 0.98, 'No axes on this figure')

# %%
fig, ax_lst = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes

# %%
math.factorial(6)
# Out:
# 720
