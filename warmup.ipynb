# %%
import pydataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
#     Use pydataset to load the mpg dataset.
#     Visualize highway mileage (hwy) on the y-axis against engine displacement (displ) on the x-axis.
#     Add meaningful labels and a title.
#     Add a horizontal dotted line that indicates the average highway mileage.
#     Add a vertical dotted line that indicates the average engine displacement.
#     Use color to indicate the number of cylinders (cyl) each car's engine has.
#     Instead of color, use seperate subplots to indicate the number of cylinders.

# %%
 sns.set_palette("husl",3)

# %%
plt.style.use('ggplot')

# %% [markdown]
# PLT.RC sets defaults for the rest of this notebook's matplotlib plotting

# %%
plt.rc('figure', figsize=(12,20))

# %% [markdown]
#     Use pydataset to load the mpg dataset.

# %%
df = pydataset.data('mpg')

# %%
df.cyl = df.cyl.astype('object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
# manufacturer    234 non-null object
# model           234 non-null object
# displ           234 non-null float64
# year            234 non-null int64
# cyl             234 non-null object
# trans           234 non-null object
# drv             234 non-null object
# cty             234 non-null int64
# hwy             234 non-null int64
# fl              234 non-null object
# class           234 non-null object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 21.9+ KB

# %% [markdown]
#     Visualize highway mileage (hwy) on the y-axis against engine displacement (displ) on the x-axis.
#        Add meaningful labels and a title.
#        Add a horizontal dotted line that indicates the average highway mileage.

# %%
sns.scatterplot(data=df, y='hwy', x='displ')
plt.title("Highway Mileage per Engine Displacement")
plt.axhline(y=hwy_mean, ls='--', color='black')
# plt.legend(loc='upper right')

# %%
hwy_mean = df.hwy.mean()

# %%
displ_mean = df.displ.mean()

# %%
x = np.arange(0,10,1)

# %% [markdown]
# Add a vertical dotted line that indicates the average engine displacement.

# %%
sns.scatterplot(data=df, y='hwy', x='displ')
plt.title("Highway Mileage per Engine Displacement")
plt.axhline(y=hwy_mean, ls='--', color='y')
plt.axvline(x=displ_mean, linewidth=2, color='b')
# plt.legend(loc='upper right')

# %% [markdown]
#      Use color to indicate the number of cylinders (cyl) each car's engine has.

# %%
df.cyl.head()
# Out:
# 1    4
# 2    4
# 3    4
# 4    4
# 5    6
# Name: cyl, dtype: object

# %%
sns.scatterplot(data=df, y='hwy', x='displ', hue='cyl')
plt.title("Highway Mileage per Engine Displacement")
plt.axhline(y=hwy_mean, ls='--')
plt.axvline(x=displ_mean, linewidth=4, color='b')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-b908c327ba5d> in <module>
# ----> 1 sns.scatterplot(data=df, y='hwy', x='displ', hue='cyl')
#       2 plt.title("Highway Mileage per Engine Displacement")
#       3 plt.axhline(y=hwy_mean, ls='--')
#       4 plt.axvline(x=displ_mean, linewidth=4, color='b')
#
# /usr/local/anaconda3/lib/python3.7/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1333         x_bins=x_bins, y_bins=y_bins,
#    1334         estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1335         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#    1336     )
#    1337
#
# /usr/local/anaconda3/lib/python3.7/site-packages/seaborn/relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     857         )
#     858
# --> 859         self.parse_hue(plot_data["hue"], palette, hue_order, hue_norm)
#     860         self.parse_size(plot_data["size"], sizes, size_order, size_norm)
#     861         self.parse_style(plot_data["style"], markers, None, style_order)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/seaborn/relational.py in parse_hue(self, data, palette, order, norm)
#     373
#     374             levels, palette, cmap, norm = self.numeric_to_palette(
# --> 375                 data, order, palette, norm
#     376             )
#     377             limits = norm.vmin, norm.vmax
#
# /usr/local/anaconda3/lib/python3.7/site-packages/seaborn/relational.py in numeric_to_palette(self, data, order, palette, norm)
#     258
#     259         if not norm.scaled():
# --> 260             norm(np.asarray(data.dropna()))
#     261
#     262         # TODO this should also use color_lookup, but that needs the
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py in __call__(self, value, clip)
#     907         result, is_scalar = self.process_value(value)
#     908
# --> 909         self.autoscale_None(result)
#     910         # Convert at least to float, without losing precision.
#     911         (vmin,), _ = self.process_value(self.vmin)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py in autoscale_None(self, A)
#     951         A = np.asanyarray(A)
#     952         if self.vmin is None and A.size:
# --> 953             self.vmin = A.min()
#     954         if self.vmax is None and A.size:
#     955             self.vmax = A.max()
#
# /usr/local/anaconda3/lib/python3.7/site-packages/numpy/ma/core.py in min(self, axis, out, fill_value, keepdims)
#    5600         if out is None:
#    5601             result = self.filled(fill_value).min(
# -> 5602                 axis=axis, out=out, **kwargs).view(type(self))
#    5603             if result.ndim:
#    5604                 # Set the mask
#
# AttributeError: 'int' object has no attribute 'view'

# %% [markdown]
#       Instead of color, use seperate subplots to indicate the number of cylinders

# %%
g = sns.FacetGrid(df, col="cyl")
g.map(plt.scatter, "displ", "hwy", alpha=.7)
#g.axhline(y=hwy_mean, ls='--')
#plt.axvline(x=displ_mean, linewidth=4, color='b')
